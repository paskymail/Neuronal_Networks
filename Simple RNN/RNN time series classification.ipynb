# %% [markdown]
# # RNN based on time series: Predict Action and next steps

# %% [markdown]
# We aim to predict the next steps and actions based on time series

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import pathlib

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import pprint as pprint

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.1.0

# %%
import tensorflow_docs as tfdocs
import tensorflow_docs.plots
import tensorflow_docs.modeling

# %% [markdown]
# ### Get the data
# First Import it using pandas

# %%
raw_dataset = pd.read_csv("./fromStateToAction_df2.csv")

dataset = raw_dataset.copy()

# %% [markdown]
# We need all the path to have the same steps. Therefore we will trunk the path to the same lenght and omit those with reduced lenght

# %% [markdown]
# First we check with is the most common lenght

# %%
len_stat = dataset.groupby(["id_camino"]).size().reset_index(name='counts')
plt.plot(len_stat.groupby(["counts"]).size(), label ="number of paths per number of steps")
plt.legend()

# %% [markdown]
# We will cut at CUT_STEP steps (n=CUT_STEP+1) and remove the path with less than 4 steps

# %%
N_STEPS= 6

long_paths = len_stat[len_stat.counts>N_STEPS]
red_dataset = dataset.loc[dataset["id_camino"].isin(long_paths["id_camino"])]
reg_dataset= red_dataset[red_dataset.id_in_seq< (N_STEPS+1)] 
reg_dataset.head()
# Out:
#     id_camino  id_in_seq                                      current_state  \
# 20          8          0                                 [0, 0, 1, 0, 0, 0]
# 21          8          1  [557.2873618367145, -88.35404417578944, 1.9044...
# 22          8          2  [1114.996313868046, -148.75498736770038, 1.794...
# 23          8          3  [1676.8499244084107, -212.92073093890662, 1.78...
# 24          8          4  [2237.5875630469245, -276.99235127691014, 1.79...
#
#                                            goal_state  out_action   timesteps
# 20  [3355.2520452554118, -366.8261847192736, 1.151...           2  315.345581
# 21  [3355.2520452554118, -366.8261847192736, 1.151...           2  315.345581
# 22  [3355.2520452554118, -366.8261847192736, 1.151...           2  315.345581
# 23  [3355.2520452554118, -366.8261847192736, 1.151...           2  315.345581
# 24  [3355.2520452554118, -366.8261847192736, 1.151...           3  315.345581

# %% [markdown]
# Finaly, the new goal state is the last state of each path
# goal state = Path[4]

# %%
for id in reg_dataset["id_camino"]:
     dummy = "a"
     dummy = reg_dataset.loc[(reg_dataset["id_camino"] == id) & (reg_dataset["id_in_seq"] == 4)].current_state
     for index in reg_dataset[reg_dataset["id_camino"] == id]:
         reg_dataset["goal_state"][index] = dummy

reg_dataset.head()
# Out:
#     id_camino  id_in_seq                                      current_state  \
# 20          8          0                                 [0, 0, 1, 0, 0, 0]
# 21          8          1  [557.2873618367145, -88.35404417578944, 1.9044...
# 22          8          2  [1114.996313868046, -148.75498736770038, 1.794...
# 23          8          3  [1676.8499244084107, -212.92073093890662, 1.78...
# 24          8          4  [2237.5875630469245, -276.99235127691014, 1.79...
#
#                                            goal_state  out_action   timesteps
# 20  [3355.2520452554118, -366.8261847192736, 1.151...           2  315.345581
# 21  [3355.2520452554118, -366.8261847192736, 1.151...           2  315.345581
# 22  [3355.2520452554118, -366.8261847192736, 1.151...           2  315.345581
# 23  [3355.2520452554118, -366.8261847192736, 1.151...           2  315.345581
# 24  [3355.2520452554118, -366.8261847192736, 1.151...           3  315.345581

# %%
reg_dataset["goal_state"]

# %%
dataset = reg_dataset

for index, row in dataset.iterrows():
    CS_array =np.array(eval(row["current_state"]))
    dataset["current_state"][index] = CS_array
    GS_array =np.array(eval(row["goal_state"]))
    dataset["goal_state"][index] = GS_array
    dataset["out_action"][index] = int(dataset["out_action"][index])

dataset["Difference"] =   dataset["goal_state"]-dataset["current_state"]

dataset[["C0",'C1',"C2","C3",'C4',"C5"]] = pd.DataFrame(dataset.current_state.values.tolist(), index= dataset.index)
dataset[["D0",'D1',"D2","D3",'D4',"D5"]] = pd.DataFrame(dataset.Difference.values.tolist(), index= dataset.index)

# %%
dataset[0:10]
# Out:
#     id_camino  id_in_seq                                      current_state  \
# 20          8          0                                 [0, 0, 1, 0, 0, 0]
# 21          8          1  [557.2873618367145, -88.35404417578944, 1.9044...
# 22          8          2  [1114.996313868046, -148.75498736770038, 1.794...
# 23          8          3  [1676.8499244084107, -212.92073093890662, 1.78...
# 24          8          4  [2237.5875630469245, -276.99235127691014, 1.79...
# 25          8          5  [2708.8805729525343, -316.7490639451525, 1.548...
# 26          8          6  [3124.473889470892, -349.2250534721162, 1.3069...
# 27          9          0                                 [0, 0, 1, 0, 0, 0]
# 28          9          1  [467.51084210168455, -52.85735936140974, 1.396...
# 29          9          2  [881.3909271559311, -87.82787195861813, 1.3092...
#
#                                            goal_state  out_action   timesteps  \
# 20  [3355.2520452554118, -366.8261847192736, 1.151...           2  315.345581
# 21  [3355.2520452554118, -366.8261847192736, 1.151...           2  315.345581
# 22  [3355.2520452554118, -366.8261847192736, 1.151...           2  315.345581
# 23  [3355.2520452554118, -366.8261847192736, 1.151...           2  315.345581
# 24  [3355.2520452554118, -366.8261847192736, 1.151...           3  315.345581
# 25  [3355.2520452554118, -366.8261847192736, 1.151...           4  315.345581
# 26  [3355.2520452554118, -366.8261847192736, 1.151...           5  315.345581
# 27  [2907.0542848353966, -263.57882736991, 1.16306...           3  315.345581
# 28  [2907.0542848353966, -263.57882736991, 1.16306...           4  315.345581
# 29  [2907.0542848353966, -263.57882736991, 1.16306...           4  315.345581
#
#                                            Difference           C0  \
# 20  [3355.2520452554118, -366.8261847192736, 0.151...     0.000000
# 21  [2797.9646834186974, -278.47214054348416, -0.7...   557.287362
# 22  [2240.255731387366, -218.07119735157323, -0.64...  1114.996314
# 23  [1678.402120847001, -153.905453780367, -0.6384...  1676.849924
# 24  [1117.6644822084872, -89.83383344236347, -0.64...  2237.587563
# 25  [646.3714723028775, -50.07712077412111, -0.397...  2708.880573
# 26  [230.77815578451964, -17.60113124715741, -0.15...  3124.473889
# 27  [2907.0542848353966, -263.57882736991, 0.16306...     0.000000
# 28  [2439.5434427337123, -210.72146800850027, -0.2...   467.510842
# 29  [2025.6633576794657, -175.7509554112919, -0.14...   881.390927
#
#             C1        C2        C3        C4        C5           D0  \
# 20    0.000000  1.000000  0.000000  0.000000  0.000000  3355.252045
# 21  -88.354044  1.904406  0.117667 -0.007043  0.001597  2797.964683
# 22 -148.754987  1.794546  0.119579 -0.059903  0.000014  2240.255731
# 23 -212.920731  1.789949  0.119717 -0.045089 -0.000059  1678.402121
# 24 -276.992351  1.794838  0.119611 -0.047056  0.000015  1117.664482
# 25 -316.749064  1.548486  0.142751 -0.009761  0.001180   646.371472
# 26 -349.225053  1.306934  0.164246  0.062756 -0.000022   230.778156
# 27    0.000000  1.000000  0.000000  0.000000  0.000000  2907.054285
# 28  -52.857359  1.396266  0.147218  0.014904 -0.002213  2439.543443
# 29  -87.827872  1.309273  0.164303  0.046378  0.000011  2025.663358
#
#             D1        D2        D3        D4        D5
# 20 -366.826185  0.151482  0.183113  0.052711 -0.001145
# 21 -278.472141 -0.752924  0.065446  0.059754 -0.002742
# 22 -218.071197 -0.643064  0.063534  0.112614 -0.001159
# 23 -153.905454 -0.638468  0.063397  0.097800 -0.001086
# 24  -89.833833 -0.643357  0.063503  0.099767 -0.001159
# 25  -50.077121 -0.397004  0.040363  0.062472 -0.002324
# 26  -17.601131 -0.155453  0.018868 -0.010045 -0.001122
# 27 -263.578827  0.163066  0.182490  0.065083 -0.000678
# 28 -210.721468 -0.233200  0.035272  0.050179  0.001535
# 29 -175.750955 -0.146207  0.018187  0.018705 -0.000689

# %% [markdown]
# ### Clean the data
#
#
# check if the data contains unknown values.

# %%
dataset.isna().sum()
# Out:
# id_camino        0
# id_in_seq        0
# current_state    0
# goal_state       0
# out_action       0
# timesteps        0
# Difference       0
# C0               0
# C1               0
# C2               0
# C3               0
# C4               0
# C5               0
# D0               0
# D1               0
# D2               0
# D3               0
# D4               0
# D5               0
# dtype: int64

# %% [markdown]
# To keep this initial tutorial simple drop those rows.

# %%
dataset = dataset.dropna()

# %% [markdown]
# ### Split the data into train and test
#
# Now split the dataset into a training set and a test set.
#
# We take the first TRAIN_SPLIT values as train data
#
# We will use the test set in the final evaluation of our model.

# %%
dataset  = dataset[["id_in_seq","D0",'D1',"D2","D3",'D4',"D5","out_action"]]

# %% [markdown]
# ### Split features from labels
#
# Separate the target value, or "label", from the features. This label is the value that you will train the model to predict.

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index, step):
    indices = range(i-history_size, i)
    data.append(dataset[indices])

    if single_step:
      labels.append(target[i+target_size])
    else:
      labels.append(target[i:i+target_size])

  return np.array(data), np.array(labels)

# %%
dataset2 = dataset.values

# %%
TRAIN_SPLIT = 9000
past_history = N_STEPS
future_target = 0
STEP = N_STEPS+1

x_train_single, y_train_single = multivariate_data(dataset2, dataset2[:, 7], 0,
                                                   TRAIN_SPLIT, past_history,
                                                   future_target, STEP,
                                                   single_step=True)
x_val_single, y_val_single = multivariate_data(dataset2, dataset2[:, 7],
                                               TRAIN_SPLIT, None, past_history,
                                               future_target, STEP,
                                               single_step=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-153-2657c195d51c> in <module>
#       7                                                    TRAIN_SPLIT, past_history,
#       8                                                    future_target, STEP,
# ----> 9                                                    single_step=True)
#      10 x_val_single, y_val_single = multivariate_data(dataset2, dataset2[:, 7],
#      11                                                TRAIN_SPLIT, None, past_history,
#
# <ipython-input-149-d94f8ed6039a> in multivariate_data(dataset, target, start_index, end_index, history_size, target_size, step, single_step)
#      10   for i in range(start_index, end_index, step):
#      11     indices = range(i-history_size, i)
# ---> 12     data.append(dataset[indices])
#      13
#      14     if single_step:
#
# IndexError: index 5243 is out of bounds for axis 0 with size 5243

# %% [markdown]
# It is good practice to normalize features that use different scales and ranges. Although the model *might* converge without feature normalization, it makes training more difficult, and it makes the resulting model dependent on the choice of units used in the input.
#
# Note: Although we intentionally generate these statistics from only the training dataset, these statistics will also be used to normalize the test dataset. We need to do that to project the test dataset into the same distribution that the model has been trained on.

# %%
def norm(x):
  return (x - train_stats['mean']) / train_stats['std']
# normed_train_data = norm(train_dataset)
# normed_test_data = norm(test_dataset)

# %% [markdown]
# This normalized data is what we will use to train the model.
#
# Caution: The statistics used to normalize the inputs here (mean and standard deviation) need to be applied to any other data that is fed to the model, along with the one-hot encoding that we did earlier.  That includes the test set as well as live data when the model is used in production.

# %%
print ('Single window of past history : {}'.format(x_train_single[0].shape))
# Out:
# Single window of past history : (4, 8)

# %% [markdown]
# ## The model

# %% [markdown]
# ### Build the model
#
# Let's build our model. Here, we'll use a `Sequential` model with two densely connected hidden layers, and an output layer that returns a single, continuous value. The model building steps are wrapped in a function, `build_model`, since we'll create a second model, later on.

# %%
BATCH_SIZE = 50
BUFFER_SIZE = 10000

train_data_single = tf.data.Dataset.from_tensor_slices((x_train_single, y_train_single))
train_data_single = train_data_single.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_single = tf.data.Dataset.from_tensor_slices((x_val_single, y_val_single))
val_data_single = val_data_single.batch(BATCH_SIZE).repeat()

# %%
single_step_model = tf.keras.models.Sequential()
single_step_model.add(tf.keras.layers.LSTM(32,
                                           input_shape=x_train_single.shape[-2:]))
single_step_model.add(tf.keras.layers.Dense(6))

single_step_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Inspect the model
#
# Use the `.summary` method to print a simple description of the model

# %%
single_step_model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_10 (LSTM)               (None, 32)                5248
# _________________________________________________________________
# dense_7 (Dense)              (None, 6)                 198
# =================================================================
# Total params: 5,446
# Trainable params: 5,446
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now try out the model. Take a batch of BATCH_SIZE examples from the training data and call `model.predict` on it.

# %%
for x, y in val_data_single.take(1):
  print(single_step_model.predict(x).shape)
# Out:
# (50, 6)

# %% [markdown]
# It seems to be working, and it produces a result of the expected shape and type.

# %% [markdown]
# ### Train the model
#
# Train the model for 1000 epochs, and record the training and validation accuracy in the `history` object.

# %%
EVALUATION_INTERVAL = 200
EPOCHS = 10

single_step_history = single_step_model.fit(train_data_single, epochs=EPOCHS,
                                            steps_per_epoch=EVALUATION_INTERVAL,
                                            validation_data=val_data_single,
                                            validation_steps=50)
# Out:
# Train for 200 steps, validate for 50 steps
# Epoch 1/10
# 200/200 [==============================] - 8s 38ms/step - loss: 1.5539 - accuracy: 0.4599 - val_loss: 1.4809 - val_accuracy: 0.4886
# Epoch 2/10
# 200/200 [==============================] - 3s 14ms/step - loss: 1.4084 - accuracy: 0.4656 - val_loss: 1.3491 - val_accuracy: 0.4886
# Epoch 3/10
# 200/200 [==============================] - 2s 11ms/step - loss: 1.3044 - accuracy: 0.4862 - val_loss: 1.2762 - val_accuracy: 0.5169
# Epoch 4/10
# 200/200 [==============================] - 2s 12ms/step - loss: 1.2376 - accuracy: 0.5138 - val_loss: 1.1964 - val_accuracy: 0.5411
# Epoch 5/10
# 200/200 [==============================] - 2s 12ms/step - loss: 1.1908 - accuracy: 0.5315 - val_loss: 1.1546 - val_accuracy: 0.5275
# Epoch 6/10
# 200/200 [==============================] - 2s 11ms/step - loss: 1.1551 - accuracy: 0.5401 - val_loss: 1.1072 - val_accuracy: 0.5538
# Epoch 7/10
# 200/200 [==============================] - 3s 14ms/step - loss: 1.1160 - accuracy: 0.5528 - val_loss: 1.0822 - val_accuracy: 0.5588
# Epoch 8/10
# 200/200 [==============================] - 2s 11ms/step - loss: 1.0863 - accuracy: 0.5549 - val_loss: 1.0424 - val_accuracy: 0.5741
# Epoch 9/10
# 200/200 [==============================] - 2s 11ms/step - loss: 1.0542 - accuracy: 0.5714 - val_loss: 1.0091 - val_accuracy: 0.5898
# Epoch 10/10
# 200/200 [==============================] - 3s 13ms/step - loss: 1.0246 - accuracy: 0.5828 - val_loss: 0.9941 - val_accuracy: 0.5627

# %% [markdown]
# Visualize the model's training progress.

# %%
def plot_train_history(history, title):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(loss))

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title(title)
  plt.legend()

  plt.show()

# %%
plot_train_history(single_step_history,
                   'Single Step Training and validation loss')

# %% [markdown]
# ## Predict a single step future

# %%
probability_model = tf.keras.Sequential([single_step_model, 
                                         tf.keras.layers.Softmax()])

# %%
def show_plot(plot_data, delta, title):
  labels = ['History', 'True Future', 'Model Prediction']
  marker = ['.-', 'rx', 'go']
  time_steps = create_time_steps(plot_data[0].shape[0])
  if delta:
    future = delta
  else:
    future = 0

  plt.title(title)
  for i, x in enumerate(plot_data):
    if i:
      plt.plot(future, plot_data[i], marker[i], markersize=10,
               label=labels[i])
    else:
      plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
  plt.legend()
  plt.xlim([time_steps[0], (future+5)*2])
  plt.xlabel('Time-Step')
  return plt

# %%
def create_time_steps(length):
  return list(range(-length, 0))

# %%
for x, y in val_data_single.take(3):
  plot = show_plot([x[0][:, 7].numpy(), y[0].numpy(),
                    np.argmax(probability_model.predict(x)[0])], 0,
                   'Single Step Prediction')
  plot.show()

# %% [markdown]
# # Multi-Step model

# %%
TRAIN_SPLIT = 40
future_target = 2
STEP = N_STEPS+1
past_history = STEP - future_target

x_train_multi, y_train_multi = multivariate_data(dataset2, dataset2[:, 7], 0,
                                                   TRAIN_SPLIT, past_history,
                                                   future_target, STEP,
                                                   single_step=False)
x_val_multi, y_val_multi = multivariate_data(dataset2, dataset2[:, 7],
                                               TRAIN_SPLIT, None, past_history,
                                               future_target, STEP,
                                               single_step=False)

# %% [markdown]
# We check that the data and label sets have the correct size

# %%
print ('Single window of past history : {}'.format(x_train_multi[0].shape))
print ('\n Target Action to predict : {}'.format(y_train_multi[0].shape))
# Out:
# Single window of past history : (5, 8)
#
#  Target Action to predict : (2,)

# %% [markdown]
# We prepate the chunks

# %%
BATCH_SIZE = 50
BUFFER_SIZE = 10000

train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %% [markdown]
# We plot a true future

# %%
def multi_step_plot(history, true_future, prediction):
  plt.figure(figsize=(12, 6))
  num_in = create_time_steps(len(history))
  num_out = len(true_future)

  plt.plot(num_in, np.array(history[:, 7]), label='History')
  plt.plot(np.arange(num_out), np.array(true_future), 'bo',
           label='True Future')
  if prediction.any():
    plt.plot(np.arange(num_out), np.array(prediction), 'ro',
             label='Predicted Future')
  plt.legend(loc='upper left')
  plt.show()

# %%
for x, y in train_data_multi.take(1):
  multi_step_plot(x[0], y[0], np.array([0]))

# %% [markdown]
# Here is the model with 2 layers. The last layer has the number of predictions as outputs

# %%
multi_step_model = tf.keras.models.Sequential()
multi_step_model.add(tf.keras.layers.LSTM(32,
                                          return_sequences=True,
                                          input_shape=x_train_multi.shape[-2:]))
multi_step_model.add(tf.keras.layers.LSTM(16, activation='relu'))
multi_step_model.add(tf.keras.layers.Dense(future_target))

multi_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(clipvalue=1.0), loss='mae')

# %%
multi_step_model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_13 (LSTM)               (None, 5, 32)             5248
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 16)                3136
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 34
# =================================================================
# Total params: 8,418
# Trainable params: 8,418
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# This is the prediction shape, which should be (BATCHSIZE, # predicted points)

# %%
for x, y in val_data_multi.take(1):
  print (multi_step_model.predict(x).shape)
# Out:
# (50, 2)

# %% [markdown]
# We train the model

# %%
multi_step_history = multi_step_model.fit(train_data_multi, epochs=EPOCHS,
                                          steps_per_epoch=EVALUATION_INTERVAL,
                                          validation_data=val_data_multi,
                                          validation_steps=50)
# Out:
# Train for 200 steps, validate for 50 steps
# Epoch 1/10
# 200/200 [==============================] - 13s 63ms/step - loss: 1.1112 - val_loss: 1.2259
# Epoch 2/10
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2676 - val_loss: 1.1577
# Epoch 3/10
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2643 - val_loss: 1.2382
# Epoch 4/10
# 200/200 [==============================] - 3s 14ms/step - loss: 0.2612 - val_loss: 1.3437
# Epoch 5/10
# 200/200 [==============================] - 3s 16ms/step - loss: 0.2588 - val_loss: 1.3451
# Epoch 6/10
# 200/200 [==============================] - 3s 14ms/step - loss: 0.2571 - val_loss: 1.2835
# Epoch 7/10
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2556 - val_loss: 1.2856
# Epoch 8/10
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2542 - val_loss: 1.2649
# Epoch 9/10
# 200/200 [==============================] - 3s 14ms/step - loss: 0.2525 - val_loss: 1.2785
# Epoch 10/10
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2510 - val_loss: 1.1794

# %%
plot_train_history(multi_step_history, 'Multi-Step Training and validation loss')

# %% [markdown]
# let's check the predictions

# %%
for x, y in val_data_multi.take(3):
  multi_step_plot(x[0], y[0], multi_step_model.predict(x)[0])
